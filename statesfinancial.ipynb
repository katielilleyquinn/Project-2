# %%
import pandas as pd

csv_file = "statesfinancial.csv"
statesfinancial_df = pd.read_csv(csv_file)
statesfinancial_df
# Out:
#             PRIMARY_KEY          STATE  YEAR   ENROLL  TOTAL_REVENUE  \
# 0          2010_ALABAMA        ALABAMA  2010   748889        7281058
# 1           2010_ALASKA         ALASKA  2010   131265        2230338
# 2          2010_ARIZONA        ARIZONA  2010   963517        8828122
# 3         2010_ARKANSAS       ARKANSAS  2010   474897        5069272
# 4       2010_CALIFORNIA     CALIFORNIA  2010  6213958       67356719
# ..                  ...            ...   ...      ...            ...
# 199       2016_VIRGINIA       VIRGINIA  2016  1283493       16259274
# 200     2016_WASHINGTON     WASHINGTON  2016  1083973       14964364
# 201  2016_WEST_VIRGINIA  WEST_VIRGINIA  2016   276764        3391579
# 202      2016_WISCONSIN      WISCONSIN  2016   857736       11697466
# 203        2016_WYOMING        WYOMING  2016    94511        2044669
#
#      FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %%
states_financial_clean = statesfinancial_df.drop(columns=['AVG_MATH_4_SCORE', 'AVG_MATH_8_SCORE' , 'AVG_READING_4_SCORE' , 'AVG_READING_8_SCORE', 'GRADES_PK_G', 'GRADES_1_8_G' , 'GRADES_KG_G' , 'GRADES_4_G' , 'GRADES_8_G' , 'GRADES_12_G' , 'GRADES_9_12_G' , 'GRADES_ALL_G'
                                 , 'LOCAL_REVENUE' , 'SUPPORT_SERVICES_EXPENDITURE' , 'OTHER_EXPENDITURE' , 'CAPITAL_OUTLAY_EXPENDITURE', 'PRIMARY_KEY'
            ])
states_financial_clean
# Out:
#              STATE  YEAR   ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0          ALABAMA  2010   748889        7281058          1134111
# 1           ALASKA  2010   131265        2230338           366970
# 2          ARIZONA  2010   963517        8828122          1579806
# 3         ARKANSAS  2010   474897        5069272           787738
# 4       CALIFORNIA  2010  6213958       67356719          9715980
# ..             ...   ...      ...            ...              ...
# 199       VIRGINIA  2016  1283493       16259274          1058146
# 200     WASHINGTON  2016  1083973       14964364          1097684
# 201  WEST_VIRGINIA  2016   276764        3391579           358068
# 202      WISCONSIN  2016   857736       11697466           782610
# 203        WYOMING  2016    94511        2044669           123012
#
#      STATE_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE
# 0          3800128            7647571                  3900492
# ...

# %%
filteredstates = states_financial_clean.loc[states_financial_clean["YEAR"] == 2016, :]
filteredstates
# Out:
#                     STATE  YEAR   ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 153               ALABAMA  2016   734652        7498567           797631
# 154                ALASKA  2016   132477        2494691           307320
# 155               ARIZONA  2016   938274        8503034          1160908
# 156              ARKANSAS  2016   479177        5401016           593656
# 157            CALIFORNIA  2016  6217031       89217262          7709079
# 158              COLORADO  2016   880678       10123271           713914
# 159           CONNECTICUT  2016   499494       11419673           468595
# 160              DELAWARE  2016   121225        2043577           134412
# 161  DISTRICT_OF_COLUMBIA  2016    48336        1329719           154922
# 162               FLORIDA  2016  2776933       28125598          3147329
# 163               GEORGIA  2016  1727085       19403453          1807371
# 164                HAWAII  2016   181995        3030519           261131
# ...

# %%
filteredstates.to_csv(r'C:\Users\kq921\Project-2\File Name.csv', index = False)
