# %%
#Dependencies
# %matplotlib inline
from matplotlib import style
from IPython.display import display, HTML
import os
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Input Paths
filename1 = "data_2010.csv"
filename2 = "data_2012.csv"
filename3 = "data_2014.csv"
filename4 = "data_2016.csv"

# %%
#Import
df1 = pd.read_csv(filename1, header=0, index_col=0)
df2 = pd.read_csv(filename2, header=0, index_col=0)
df3 = pd.read_csv(filename3, header=0, index_col=0)
df4 = pd.read_csv(filename4, header=0, index_col=0)

# %%
df1.head()
# Out:
#             Percent of High School Graduates Going Directly to College (%)  \
# Alabama                                                  63.2
# Alaska                                                   46.4
# Arizona                                                  57.9
# Arkansas                                                 65.4
# California                                               61.7
#
#             High School Graduates - 2010  \
# Alabama                            48443
# Alaska                              8434
# Arizona                            63900
# Arkansas                           29606
# California                        440243
#
#             First-Time Freshmen Directly from High School Enrolled Anywhere in the US - Fall 2010
# Alabama                                                 30616
# Alaska                                                   3915
# Arizona                                                 37006
# ...

# %%
df2.head()
# Out:
#             Percent of High School Graduates Going Directly to College (%)  \
# Alabama                                                  59.1
# Alaska                                                   45.9
# Arizona                                                  53.5
# Arkansas                                                 67.8
# California                                               58.4
#
#             High School Graduates - 2012  \
# Alabama                            50263
# Alaska                              8159
# Arizona                            65977
# Arkansas                           29807
# California                        453078
#
#             First-Time Freshmen Directly from High School Enrolled Anywhere in the US - Fall 2012
# Alabama                                                 29704
# Alaska                                                   3747
# Arizona                                                 35265
# ...

# %%
df3.head()
# Out:
#             Percent of High School Graduates Going Directly to College (%)  \
# Alabama                                                  62.1
# Alaska                                                   44.0
# Arizona                                                  52.3
# Arkansas                                                 63.5
# California                                               60.9
#
#             High School Graduates - 2014  \
# Alabama                            49242
# Alaska                              7964
# Arizona                            68060
# Arkansas                           30947
# California                        449202
#
#             First-Time Freshmen Directly from High School Enrolled Anywhere in the US - Fall 2014
# Alabama                                                 30583
# Alaska                                                   3507
# Arizona                                                 35598
# ...

# %%
df4.head()
# Out:
#             Percent of High School Graduates Going Directly to College (%)  \
# Alabama                                                  66.4
# Alaska                                                   43.8
# Arizona                                                  53.7
# Arkansas                                                 62.6
# California                                               63.2
#
#             High School Graduates - 2016  \
# Alabama                            49386
# Alaska                              7589
# Arizona                            67549
# Arkansas                           31144
# California                        434112
#
#             First-Time Freshmen Directly from High School Enrolled Anywhere in the US - Fall 2016
# Alabama                                                 32787
# Alaska                                                   3322
# Arizona                                                 36305
# ...
